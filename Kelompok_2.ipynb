# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhamadOskhar/Statistika-Deskriptif/blob/main/Kelompok_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program Statistika Deskriptif
"""

  Program ini digunakan untuk menampilkan informasi dari data yang dimiliki dalam bentuk tabel, hasil perhitungan, dan kurva
  1) ukuran pemusatan
    - Mean
    - Median
    - Modus

  2) ukuran penyebaran
    - Rentang
    - Deviasi rata rata
    - Varian
    - Standar Deviasi

  3) distribusi data
    - Skewness
    - Kurtosis

"""

# Deklarasi pustaka yang diperlukan
from google.colab import drive
import pandas as pd

# Hubungkan dengan google drive untuk mengakses data
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Mengambil data dari drive dan dijadikan variabel dictionary
data = pd.read_csv('gdrive/My Drive/statel/Data.csv')

# Tampilkan data sesuai jumlah data yang tersedia
data.head(data["Prodi"].count())
# Out:
#                                     Prodi  Nilai Utbk  Daya Tampung  Peminat
# 0                               Psikologi         677           100     1698
# 1                               Manajemen         674            64     1516
# 2                       Pendidikan Dokter         658            60     1322
# 3                      Teknik Informatika         656            48     1018
# 4                                 Farmasi         653            44     1011
# 5                               Akuntansi         657            64      955
# 6                        Ilmu Keperawatan         651            44      937
# 7                             Jurnalistik         632            64      872
# 8                    Kesehatan Masyarakat         651            44      867
# 9               Bahasa Dan Sastra Inggris         630            56      802
# 10                             Ilmu Hukum         620            64      793
# ...

# %%
# Mendapatkan ukuran pemusatan dengan perhitungan yang dilakukan oleh library pandas
pemusatan = {
  "rt": {
    "Peminat": data["Peminat"].mean(),
    "Daya Tampung": data["Daya Tampung"].mean(),
    "Nilai Utbk": data["Nilai Utbk"].mean()
  },
  "mdn": {
    "Peminat": data["Peminat"].median(),
    "Daya Tampung": data["Daya Tampung"].median(),
    "Nilai Utbk": data["Nilai Utbk"].median()
  },
  "mds": {
    "Peminat": data["Peminat"].max(),
    "Daya Tampung": data["Daya Tampung"].mode(),
    "Nilai Utbk": data["Nilai Utbk"].mode()
  }
}

# Menampilkan hasil data pemusatan dalam bentuk dictionary
print(f"Rata - rata = {pemusatan['rt']} \n")
print(f"Median = {pemusatan['mdn']} \n")
print(f"Modus = {pemusatan['mds']}")
# Out:
# Rata - rata = {'Peminat': 704.5769230769231, 'Daya Tampung': 49.65384615384615, 'Nilai Utbk': 623.4615384615385}
#
# Median = {'Peminat': 714.0, 'Daya Tampung': 48.0, 'Nilai Utbk': 617.5}
#
# Modus = {'Peminat': 1698, 'Daya Tampung': 0    48
# Name: Daya Tampung, dtype: int64, 'Nilai Utbk': 0    591
# 1    651
# Name: Nilai Utbk, dtype: int64}

# %%
# Mendapatkan rentang atau range dari data
penyebaran = {
    "range": {
        "Peminat": data["Peminat"].max() - data["Peminat"].min(),
        "Daya Tampung": data["Daya Tampung"].max() - data["Daya Tampung"].min(),
        "Nilai Utbk": data["Nilai Utbk"].max() - data["Nilai Utbk"].min()
    },
    "devi": {
        "Deviasi Peminat": data["Peminat"] - pemusatan["rt"]["Peminat"],
        "Deviasi Daya Tampung": data["Daya Tampung"] - pemusatan["rt"]["Daya Tampung"],
        "Deviasi Nilai Utbk": data["Nilai Utbk"] - pemusatan["rt"]["Nilai Utbk"]
    }
}


# Menampilkan range dari masing masing baris dalam tabel
print(f"Rentang = {penyebaran['range']} \n")

# Menampilkan deviasi dari setiap data dalam bentuk tabel
deviasi = pd.DataFrame(penyebaran['devi'])
deviasi.head(deviasi["Deviasi Peminat"].count())
# Out:
# Rentang = {'Peminat': 1590, 'Daya Tampung': 69, 'Nilai Utbk': 97}
#     Deviasi Peminat  Deviasi Daya Tampung  Deviasi Nilai Utbk
# 0        993.423077             50.346154           53.538462
# 1        811.423077             14.346154           50.538462
# 2        617.423077             10.346154           34.538462
# 3        313.423077             -1.653846           32.538462
# 4        306.423077             -5.653846           29.538462
# 5        250.423077             14.346154           33.538462
# 6        232.423077             -5.653846           27.538462
# 7        167.423077             14.346154            8.538462
# 8        162.423077             -5.653846           27.538462
# 9         97.423077              6.346154            6.538462
# 10        88.423077             14.346154           -3.461538
# 11        83.423077             -9.653846           13.538462
# 12        51.423077             -1.653846          -10.461538
# ...

# %%
# Mendapatkan deviasi rata rata
rt_deviasi = deviasi.mean()

# Menampilkan hasil
print("Deviasi rata rata masing masing baris")
pd.DataFrame(rt_deviasi)
# Out:
# Deviasi rata rata masing masing baris
#                                  0
# Deviasi Peminat      -1.749028e-14
# Deviasi Daya Tampung  5.465713e-16
# Deviasi Nilai Utbk    8.745141e-15

# %%
# Mendapatkan varians dari data
varians = data.var(numeric_only=True)

# Menampilkan hasil
print("Varians masing masing baris")
pd.DataFrame(varians)
# Out:
# Varians masing masing baris
#                           0
# Nilai Utbk       820.258462
# Daya Tampung     209.035385
# Peminat       173306.653846

# %%
# Mendapatkan standar deviasi
s_dev = varians ** 0.5

# Menampilkan hasil
print("Standar deviasi masing masing baris")
pd.DataFrame(s_dev)
# Out:
# Standar deviasi masing masing baris
#                        0
# Nilai Utbk     28.640155
# Daya Tampung   14.458056
# Peminat       416.301158

# %%
# Deklarasi pustaka yang dibutuhkan untuk membuat kurva
import seaborn as sns
from scipy import stats

# Membuat kurva distribusi normal dari data Peminat
sns.kdeplot(
    stats.norm(pemusatan["rt"]["Peminat"], s_dev["Peminat"]).rvs(25),
    color="teal",
    fill=True
)

# Membuat kurva distribusi normal dari data Nilai Utbk
sns.kdeplot(
    stats.norm(pemusatan["rt"]["Nilai Utbk"], s_dev["Nilai Utbk"]).rvs(25),
    color="skyblue",
    fill=True
)

# Membuat kurva distribusi normal dari data Daya Tampung
sns.kdeplot(
    stats.norm(pemusatan["rt"]["Daya Tampung"], s_dev["Daya Tampung"]).rvs(25),
    color="gold",
    fill=True
).set(ylabel="Sumbu Y", xlabel="Sumbu X")


# Note: Semakin besar standar deviasi, maka kurva akan semakin melebar
# Out:
# [Text(0, 0.5, 'Sumbu Y'), Text(0.5, 0, 'Sumbu X')]

# %%
# Mendapatkan data skewness dari masing masin baris data
skewness = data.skew(numeric_only=True)

# Menampilkan hasil
print("Skewness masing masing baris")
pd.DataFrame(skewness)
# Out:
# Skewness masing masing baris
#                      0
# Nilai Utbk    0.326537
# Daya Tampung  1.645572
# Peminat       0.536006

# %%
# Mendapatkan data kurtosis dari masing masing baris data
kurtosis = data.kurt(numeric_only=True)

# Menampilkan hasil
print("Kurtosis masing masing baris")
pd.DataFrame(kurtosis)
# Out:
# Kurtosis masing masing baris
#                      0
# Nilai Utbk   -1.081899
# Daya Tampung  4.811482
# Peminat       0.117377

# %%
# Deklarasi Pustaka untuk menampilkan kurva dengan lebih rapih
import matplotlib.pyplot as plt

# Membuat kurva 3 baris dan 2 kolom
f, axes = plt.subplots(3, 1, figsize=(7, 7), sharex=True)

# Menampilkan kurva dengan disertai skewness dan kurtosis
sns.kdeplot(data.iloc[:,1], color="skyblue", ax=axes[0], fill=True).set(ylabel = "Nilai Utbk", xlabel="")
sns.kdeplot(data.iloc[:,2], color="gold", ax=axes[1], fill=True).set(ylabel = "Daya Tampung", xlabel="")
sns.kdeplot(data.iloc[:,3], color="teal", ax=axes[2], fill=True).set(ylabel = "Peminat", xlabel="")

# Tampilkan kurva
plt.tight_layout()

# %%
# Mendapatkan 4 nilai kuartil dari masing masing baris pada data
kuartil = data.quantile([0.25, 0.5, 0.75], numeric_only=True)

# Menampilkan hasil
print("Kuartil masing masing baris")
pd.DataFrame(kuartil)
# Out:
# Kuartil masing masing baris
#       Nilai Utbk  Daya Tampung  Peminat
# 0.25       600.5          41.0   342.25
# 0.50       617.5          48.0   714.00
# 0.75       651.0          56.0   920.75

# %%
# Mendapatkan nilai persentil dari masing masing baris pada data
persentil = data.quantile([0.3, 0.5, 0.7, 0.9])

# Menampilkan hasil
print("Persentil masing masing baris")
pd.DataFrame(persentil)
# Out:
# Persentil masing masing baris
#      Nilai Utbk  Daya Tampung  Peminat
# 0.3       603.5          44.0    462.0
# 0.5       617.5          48.0    714.0
# 0.7       644.0          52.0    869.5
# 0.9       657.5          64.0   1170.0
